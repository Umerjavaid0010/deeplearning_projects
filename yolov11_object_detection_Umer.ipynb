# %% [markdown]
# # INSTALLING THE NECESSARY LIBRARIES

# %%
# !pip install ultralytics --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.7/898.7 kB 16.8 MB/s eta 0:00:00

# %%
# Install required libraries
# !pip install opencv-python opencv-python-headless numpy matplotlib

# %% [markdown]
# **IMPORTING LIBRARIES**

# %%
from IPython.display import Image, display,Video
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !pip install opencv-python

# %%
# Make sure to import YOLO from the ultralytics module.
from ultralytics import YOLO

# Now, you should be able to use the YOLO class
model = YOLO('yolo11n.pt')
results = model('/content/WhatsApp Image 2024-12-06 at 4.03.18 PM.jpeg',save =True)
for r in results:
  print(f"Detected {len(r)} objects in image")
# Out:
# ...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 170MB/s]
# image 1/1 /content/WhatsApp Image 2024-12-06 at 4.03.18 PM.jpeg: 640x608 1 person, 2 bottles, 1 couch, 1 potted plant, 1 vase, 96.3ms
# Speed: 17.6ms preprocess, 96.3ms inference, 1916.3ms postprocess per image at shape (1, 3, 640, 608)
# Results saved to runs/detect/predict
# Detected 6 objects in image

# %% [markdown]
# **Detect on images**

# %% [markdown]
# **DISPLAY RESULTS**

# %%
display(Image(filename='/content/runs/detect/predict/WhatsApp Image 2024-12-06 at 4.03.18 PM.jpg',width=600))

# %%
results[0]
# Out:
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...

# %% [markdown]
# **Detect on Video File**

# %%
model = YOLO('yolo11n.pt')
results = model('/content/WhatsApp Video 2024-12-06 at 4.03.09 PM.mp4',save =True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/864) /content/WhatsApp Video 2024-12-06 at 4.03.09 PM.mp4: 640x384 2 cars, 145.6ms
# video 1/1 (frame 2/864) /content/WhatsApp Video 2024-12-06 at 4.03.09 PM.mp4: 640x384 2 cars, 12.2ms
# video 1/1 (frame 3/864) /content/WhatsApp Video 2024-12-06 at 4.03.09 PM.mp4: 640x384 2 cars, 16.4ms
# video 1/1 (frame 4/864) /content/WhatsApp Video 2024-12-06 at 4.03.09 PM.mp4: 640x384 2 cars, 34.5ms
# ...

# %%
# Assuming there is a video file named 'video.mp4' within the directory 'predict7'
video_path = '/content/runs/detect/predict2'
# Replace 'video.mp4' with the actual video file name

display(Video(video_path, embed=True, width=400))
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in _repr_html_(self)
#    1439                 mimetype, _ = mimetypes.guess_type(self.filename)
#    1440
# -> 1441             with open(self.filename, 'rb') as f:
#    1442                 video = f.read()
#    1443         else:
#
# IsADirectoryError: [Errno 21] Is a directory: '/content/runs/detect/predict2'

# %%
# Assuming there is a video file named 'video.mp4' within the directory 'predict2'
video_path = '/content/runs/detect/predict2/video.mp4'
# Replace 'video.mp4' with the actual video file name if different

display(Video(video_path, embed=True, width=400))
# Out:
# <video controls  width="400" >
#  <source src="....mp4" type="None">
#  Your browser does not support the video tag.
#  </video>
